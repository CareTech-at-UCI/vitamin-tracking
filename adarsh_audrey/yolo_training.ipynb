# %% [markdown]
# # YOLO Training Using Combined Dataset

# %% [markdown]
# ## Download Data

# %%
# %pip install roboflow -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 52.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 121.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 138.6 MB/s eta 0:00:00

# %%
# %pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 89.9 MB/s eta 0:00:00

# %%
from google.colab import userdata

ROBOFLOW_API_KEY = userdata.get("ROBOFLOW_API_KEY")

# %%
from roboflow import Roboflow

rf = Roboflow(api_key=ROBOFLOW_API_KEY)
project = rf.workspace("caretech-qnw0y").project("v1-caretech-combined-dataset")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to [V1]-CareTech-Combined-Dataset-1 in yolov8:: 100%|██████████| 58572/58572 [00:03<00:00, 15641.30it/s]

# %%
# !mv "[V1]-CareTech-Combined-Dataset-1" "V1-CareTech-Combined-Dataset-1"

# %%
# !cat /content/V1-CareTech-Combined-Dataset-1/data.yaml
# Out:
# names:
# - adobo
# - almond-jelly
# - apple
# - apple-pie
# - ayam-bakar
# - ayam-goreng
# - babi-guling
# - bagel
# - bak-kut-teh
# - baked-salmon
# - ball-shaped-bun-with-pork
# - barbecued-red-pork-in-sauce-with-rice
# - bean-curd-family-style
# - beef-bowl
# - beef-curry
# - beef-in-oyster-sauce
# - beef-noodle
# - beef-noodle-soup
# - bibimbap
# - boiled-chicken-and-vegetables
# - boiled-fish
# - boned-sliced-hainan-style-chicken-with-marinated-rice
# - braised-pork-meat-ball-with-napa-cabbage
# - broiled-eel-bowl
# - brownie
# - bubur-ayam
# - cabbage-roll
# - caesar-salad
# - champon
# - charcoal-boiled-pork-neck
# - chicken-cutlet
# - chicken-n-egg-on-rice
# - chicken-nugget
# - chicken-rice
# - chicken-rice-curry-with-coconut
# - chilled-noodle
# - chinese-pumpkin-pie
# - chinese-soup
# - chip-butty
# - chop-suey
# - chow-mein
# - churro
# - clear-soup
# - coconut-milk-flavored-crepes-with-shrimp-and-beef
# - coconut-milk-soup
# - cold-tofu
# - crape
# - cream-puff
# ...

# %% [markdown]
# ## Training

# %%
# !yolo detect train data=/content/V1-CareTech-Combined-Dataset-1/data.yaml model=yolo11s.pt epochs=40 imgsz=480
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.11 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA H100 80GB HBM3, 81224MiB)
# ...
