# %%
# %pip install python-dotenv
# %pip install roboflow
# %pip install supervision
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: roboflow in /usr/local/lib/python3.12/dist-packages (1.2.16)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2026.2.25)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.4)
# Requirement already satisfied: supervision in /usr/local/lib/python3.12/dist-packages (0.27.0.post1)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.12/dist-packages (from supervision) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from supervision) (1.16.3)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from supervision) (3.10.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from supervision) (6.0.3)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.12/dist-packages (from supervision) (11.3.0)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from supervision) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.12/dist-packages (from supervision) (4.67.3)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.12/dist-packages (from supervision) (4.13.0.92)
# Requirement already satisfied: pyDeprecate>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from supervision) (0.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->supervision) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->supervision) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->supervision) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->supervision) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->supervision) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.17.0)

# %%
from google.colab import userdata
userdata.get('TEST')
# Out:
# 'test'

# %%
# from dotenv import load_dotenv

# load_dotenv()

from roboflow import Roboflow

# if google colab run:
from google.colab import userdata
ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')

rf = Roboflow(api_key=ROBOFLOW_API_KEY)
project = rf.workspace("caretech-qnw0y").project("v1-caretech-combined-dataset")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in [V1]-CareTech-Combined-Dataset-1 to yolov8:: 100%|██████████| 1006628/1006628 [00:58<00:00, 17289.42it/s]
# Extracting Dataset Version Zip to [V1]-CareTech-Combined-Dataset-1 in yolov8:: 100%|██████████| 58572/58572 [00:06<00:00, 9305.40it/s]

# %%
# !mv "/content/[V1]-CareTech-Combined-Dataset-1" "/content/V1-CareTech-Combined-Dataset-1"
# !rm -rf "/content/[V1]-CareTech-Combined-Dataset-1"

# %%
# %pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (7.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.5.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.6)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.9.0.post0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (7.17.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.24.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.6.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (4.9.4)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.26.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.17.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.30.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.12.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.7)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.4.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2025.3)

# %%
# script to split training dataset
import os
import shutil
from pathlib import Path
import supervision as sv


# creates a new folder with just the images and labels
dir = Path('/content/V1-CareTech-Combined-Dataset-1')
unified_dir = Path('/content/all')
split_path = Path('/content/split')

new_img_dir = unified_dir / 'images'
new_label_dir = unified_dir / 'labels'

new_img_dir.mkdir(parents=True, exist_ok=True)
new_label_dir.mkdir(parents=True, exist_ok=True)

# write to a flattened folder
for file in dir.rglob('*.jpg'):
    shutil.copy(file, new_img_dir)

exclude = ['README.roboflow.txt', 'README.dataset.txt']
for file in dir.rglob('*.txt'):
    if str(file.name) in exclude:
        continue
    shutil.copy(file, new_label_dir)

# %%
# load dataset to get class names for EDA
import supervision as sv

ds = sv.DetectionDataset.from_yolo(
    images_directory_path=str(new_img_dir),
    annotations_directory_path=str(new_label_dir),
    data_yaml_path=str(dir / 'data.yaml')
)

print(ds.classes)
# Out:
# ['adobo', 'almond-jelly', 'apple', 'apple-pie', 'ayam-bakar', 'ayam-goreng', 'babi-guling', 'bagel', 'bak-kut-teh', 'baked-salmon', 'ball-shaped-bun-with-pork', 'barbecued-red-pork-in-sauce-with-rice', 'bean-curd-family-style', 'beef-bowl', 'beef-curry', 'beef-in-oyster-sauce', 'beef-noodle', 'beef-noodle-soup', 'bibimbap', 'boiled-chicken-and-vegetables', 'boiled-fish', 'boned-sliced-hainan-style-chicken-with-marinated-rice', 'braised-pork-meat-ball-with-napa-cabbage', 'broiled-eel-bowl', 'brownie', 'bubur-ayam', 'cabbage-roll', 'caesar-salad', 'champon', 'charcoal-boiled-pork-neck', 'chicken-cutlet', 'chicken-n-egg-on-rice', 'chicken-nugget', 'chicken-rice', 'chicken-rice-curry-with-coconut', 'chilled-
ken', 'roast-duck', 'roll-bread', 'salmon-meuniere', 'salt-and-pepper-fried-shrimp-with-shell', 'samul', 'sandwiches', 'sashimi', 'sashimi-bowl', 'sausage', 'sauteed-spinach', 'sauteed-vegetables', 'scone', 'scrambled-egg', 'seasoned-beef-with-potatoes', 'shortcake', 'shrimp-patties', 'shrimp-with-chill-source', 'simmered-pork', 'sirloin-cutlet', 'small-steamed-savory-rice-pancake', 'soba-noodle', 'sour-prawn-soup', 'spaghetti', 'spaghetti-meat-sauce', 'spam-musubi', 'spicy-chicken-salad', 'spicy-chili-flavored-tofu', 'steak', 'steamed-egg-hotchpotch', 'steamed-meat-dumpling', 'steamed-rice-roll', 'steamed-spareribs', 'stew', 'stewed-pork-leg', 'stinky-tofu', 'stir-fried-be ...

# %%
# class distribution count
from collections import defaultdict
from matplotlib import pyplot as plt
from matplotlib.ticker import MaxNLocator

class_labels = { i: ds.classes[i] for i in range(len(ds.classes)) }

class_count = defaultdict(int)
box_count = defaultdict(int)
label_dir = unified_dir / 'labels'
label_files = list(label_dir.glob('*.txt'))
print(f"Label files found: {len(label_files)}")
for file in label_files:
    count = 0
    with open(file, 'r') as f:
      for line in f:
        arr = line.split()
        if not arr:
          continue

        i = int(arr[0])
        class_count[class_labels[i]] += 1
        count += 1


    box_count[count] += 1


print(class_count)

# class distribution count
# image size
# aspect ratio
# boxes per image
# noise / blur

# plot
plt.figure(figsize=(10, 6))
plt.bar(class_count.keys(), class_count.values())
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Class Distribution')
plt.xticks(rotation=90)
plt.show()

# plot
plt.figure(figsize=(10, 6))
ax = plt.figure().gca()
plt.bar(box_count.keys(), box_count.values())
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_xlim([0, 10])
plt.xlabel('Box Count')
plt.ylabel('Count')
plt.title('Box Count Distribution')
plt.show()
# Out:
# Label files found: 29280
# defaultdict(<class 'int'>, {'nasi-campur': 114, 'ham-cutlet': 112, 'ramen-noodle': 303, 'egg-sunny-side-up': 204, 'scone': 103, 'braised-pork-meat-ball-with-napa-cabbage': 118, 'dipping-noodles': 129, 'sushi': 146, 'babi-guling': 108, 'fried-chicken': 121, 'pork-satay': 109, 'sandwiches': 157, 'minced-pork-rice': 111, 'oxtail-soup': 118, 'clear-soup': 113, 'rice': 341, 'chinese-pumpkin-pie': 102, 'croquette': 110, 'oden': 107, 'croissant': 116, 'pork-loin-cutlet': 114, 'thai-papaya-salad': 119, 'takoyaki': 134, 'oatmeal': 117, 'sauteed-vegetables': 105, 'pork-cutlet': 102, 'hot-and-sour-fish-and-vegetable-ragout': 106, 'french-bread': 102, 'eels-on-rice': 124, 'yudofu': 113, 'baked-salmon': 107, 'hamburger': 207, 'minestrone': 104, 'sukiyaki': 106, 'fried-pork-dumplings-served-in-soup': 116, 'bak-kut-teh': 107, 'okinawa-soba': 108, 'tempura-bowl': 120, 'muffin': 111, 'rice-with-roast-duck': 103, 'japanese-style-pancake': 134, 'paella': 105, 'mushroom-risotto': 113, 'eggplant-with-garlic-sauce': 113, 'sweet-and-sour-pork': 91, '
 117, 'pilaf': 109, 'pork-with-lemon': 100, 'omelet-with-fried-rice': 116, 'eight-treasure-rice': 109, 'trunip-pudding': 103, 'sauteed-spinach': 98, 'ayam-bakar': 111, 'minced-meat-cutlet': 104, 'chinese-soup': 135, 'rice-crispy-pork': 117, 'chicken-rice-curry-with-coconut': 101, 'chicken-n-egg-on-rice': 120, 'samul': 107, 'mozuku': 100, 'grilled-salmon': 103, 'green-curry': 99, 'custard-tart ...

# %%
from PIL import Image

# image size
sizes: list[tuple[int, int]] = [] # width x height
img_dir = unified_dir / 'images'
images = list(img_dir.glob('*.jpg'))
print(f"Images found: {len(images)}")
for img in images:
  with Image.open(img) as im:
    sizes.append(im.size)

ratios = [s[0] / s[1] for s in sizes]

# plot
plt.figure(figsize=(10, 6))
plt.scatter([s[0] for s in sizes], [s[1] for s in sizes])
plt.xlabel('Width')
plt.ylabel('Height')
plt.title('Image Sizes')
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(ratios, bins=100, range=(0.5, 2.5))
plt.xlabel('Aspect Ratio')
plt.ylabel('Count')
plt.title('Aspect Ratio Distribution')
plt.show()
# Out:
# Images found: 29280

# %%
import hashlib
from pathlib import Path

def remove_duplicate_images(images_dir: str, labels_dir: str):
    images_path = Path(images_dir)
    labels_path = Path(labels_dir)

    seen_hashes = {}
    duplicates = []

    for img_file in sorted(images_path.iterdir()):
        if img_file.suffix.lower() not in ('.jpg', '.jpeg', '.png', '.bmp'):
            continue
        h = hashlib.md5(img_file.read_bytes()).hexdigest()
        if h in seen_hashes:
            duplicates.append(img_file)
        else:
            seen_hashes[h] = img_file

    print(f"{len(duplicates)} duplicate images")

    for dup in duplicates:
        dup.unlink()
        label_file = labels_path / (dup.stem + '.txt')
        if label_file.exists():
            label_file.unlink()

    print(f"{len(seen_hashes)} left")

remove_duplicate_images('/content/all/images', '/content/all/labels')
# Out:
# 0 duplicate images
# 29280 left

# %%
import cv2
import numpy as np
from pathlib import Path

IMG_DIR = Path('/content/all/images')

enhanced_count = 0
for img_file in sorted(IMG_DIR.glob('*')):
    if img_file.suffix.lower() not in ('.jpg', '.jpeg', '.png'):
        continue

    img = cv2.imread(str(img_file))
    # remove stupid images
    if img is None:
        img_file.unlink()
        label_file = Path('/content/all/labels') / (img_file.stem + '.txt')
        if label_file.exists():
            label_file.unlink()
        continue

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    mean_brightness = gray.mean()
    laplacian_var = cv2.Laplacian(gray, cv2.CV_64F).var()

    needs_enhance = False

    # flag to change images (not sure if this will work; will revisit if needed)
    if mean_brightness < 50:
        needs_enhance = True

    if laplacian_var < 30 and mean_brightness < 150:
        needs_enhance = True

    if needs_enhance:
        # Apply CLAHE
        lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
        l, a, b = cv2.split(lab)
        clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
        l = clahe.apply(l)
        enhanced = cv2.merge([l, a, b])
        enhanced = cv2.cvtColor(enhanced, cv2.COLOR_LAB2BGR)
        cv2.imwrite(str(img_file), enhanced)
        enhanced_count += 1

print(f"changed {enhanced_count} images")
# Out:
# changed 262 images

# %%
from pathlib import Path
from PIL import Image, ImageOps

IMG_DIR = Path('/content/all/images')

for img_file in sorted(IMG_DIR.glob('*')):
    if img_file.suffix.lower() not in ('.jpg', '.jpeg', '.png'):
        continue
    pil_img = Image.open(img_file)
    pil_img = ImageOps.exif_transpose(pil_img)
    pil_img.save(img_file)

# %%
# Remove meatloaf class
import yaml
from pathlib import Path

LBL_DIR = Path('/content/all/labels')
DATA_YAML = Path('/content/V1-CareTech-Combined-Dataset-1/data.yaml')

with open(DATA_YAML) as f:
    data = yaml.safe_load(f)

old_names = data['names']
drop_class = 'meat-loaf'
drop_id = old_names.index(drop_class)
print(f"Dropping class '{drop_class}' (id={drop_id})")

# death to meatloaf
new_names = [n for n in old_names if n != drop_class]
remap = {}
new_id = 0
for old_id, name in enumerate(old_names):
    if old_id == drop_id:
        continue
    remap[old_id] = new_id
    new_id += 1

# drop meatloaf lines, remap remaining IDs
removed_files = 0
for lbl_file in sorted(LBL_DIR.glob('*.txt')):
    lines = lbl_file.read_text().strip().splitlines()
    new_lines = []
    for line in lines:
        parts = line.split()
        if not parts:
            continue
        cls_id = int(parts[0])
        if cls_id == drop_id:
            continue
        parts[0] = str(remap[cls_id])
        new_lines.append(' '.join(parts))

    if not new_lines:
        lbl_file.unlink()
        img_file = Path('/content/all/images') / (lbl_file.stem + '.jpg')
        if img_file.exists():
            img_file.unlink()
        removed_files += 1
    else:
        lbl_file.write_text('\n'.join(new_lines) + '\n')

# Update data.yaml
data['names'] = new_names
data['nc'] = len(new_names)
with open(DATA_YAML, 'w') as f:
    yaml.dump(data, f, sort_keys=False)

print(f"Removed {removed_files} images that only contained meatloaf")
print(f"Classes: {len(old_names)} -> {len(new_names)}")
# Out:
# Dropping class 'meat-loaf' (id=127)
# Removed 113 images that only contained meatloaf
# Classes: 258 -> 257

# %%
import random
import cv2
import numpy as np
from pathlib import Path
from collections import defaultdict


IMG_DIR = Path('/content/all/images')
LBL_DIR = Path('/content/all/labels')

class_to_images = defaultdict(set)
image_classes = defaultdict(set)

for lbl_file in LBL_DIR.glob('*.txt'):
    stem = lbl_file.stem
    with open(lbl_file) as f:
        for line in f:
            parts = line.strip().split()
            if not parts:
                continue
            cls_id = int(parts[0])
            class_to_images[cls_id].add(stem)
            image_classes[stem].add(cls_id)

total_images = len(list(IMG_DIR.glob('*.jpg')))
class_counts = {c: len(imgs) for c, imgs in class_to_images.items()}
for c in sorted(class_counts):
    print(f"Class {c}: {class_counts[c]} images")


ABLATION_RATIO = 0.10

ablation_remove = set()
for cls_id, stems in class_to_images.items():
    n_remove = max(1, int(len(stems) * ABLATION_RATIO))
    to_remove = random.sample(sorted(stems), n_remove)
    ablation_remove.update(to_remove)

for stem in ablation_remove:
    img = IMG_DIR / f"{stem}.jpg"
    lbl = LBL_DIR / f"{stem}.txt"
    if img.exists(): img.unlink()
    if lbl.exists(): lbl.unlink()

for cls_id in class_to_images:
    class_to_images[cls_id] -= ablation_remove
class_counts = {c: len(imgs) for c, imgs in class_to_images.items()}


# Threshold = median count (mean idk)
counts = sorted(class_counts.values())
UNDERSAMPLE_CAP = int(np.median(counts))
print(f"median: {UNDERSAMPLE_CAP} images")

undersample_remove = set()
for cls_id, stems in class_to_images.items():
    if len(stems) > UNDERSAMPLE_CAP:
        excess = sorted(stems)
        random.shuffle(excess)
        removed = 0
        for stem in excess:
            if removed >= len(stems) - UNDERSAMPLE_CAP:
                break
            if image_classes[stem] == {cls_id}:
                undersample_remove.add(stem)
                removed += 1
        print(f"  Class {cls_id}: removed {removed} (target was {len(stems) - UNDERSAMPLE_CAP})")

for stem in undersample_remove:
    img = IMG_DIR / f"{stem}.jpg"
    lbl = LBL_DIR / f"{stem}.txt"
    if img.exists(): img.unlink()
    if lbl.exists(): lbl.unlink()

# update counts
for cls_id in class_to_images:
    class_to_images[cls_id] -= undersample_remove
class_counts = {c: len(imgs) for c, imgs in class_to_images.items()}


#Oversampling - augmentions
OVERSAMPLE_TARGET = UNDERSAMPLE_CAP

aug_count = 0
for cls_id, stems in class_to_images.items():
    if len(stems) >= OVERSAMPLE_TARGET:
        continue

    need = OVERSAMPLE_TARGET - len(stems)
    source_stems = sorted(stems)
    print(f"  Class {cls_id}: augmenting {need} images from {len(stems)} originals")

    for i in range(need):
        src_stem = source_stems[i % len(source_stems)]
        src_img_path = IMG_DIR / f"{src_stem}.jpg"
        src_lbl_path = LBL_DIR / f"{src_stem}.txt"

        if not src_img_path.exists():
            continue

        img = cv2.imread(str(src_img_path))

        # random augmentation
        aug_type = random.choice(['brightness', 'rotate', 'shear'])

        if aug_type == 'brightness':
            beta = random.uniform(-30, 30)
            img = cv2.convertScaleAbs(img, alpha=1.0, beta=beta)
        elif aug_type == 'rotate':
            angle = random.uniform(-15, 15)
            h, w = img.shape[:2]
            M = cv2.getRotationMatrix2D((w / 2, h / 2), angle, 1.0)
            img = cv2.warpAffine(img, M, (w, h), borderValue=(114, 114, 114))
        elif aug_type == 'shear':
            shear_x = random.uniform(-0.1, 0.1)
            h, w = img.shape[:2]
            M = np.float32([[1, shear_x, 0], [0, 1, 0]])
            img = cv2.warpAffine(img, M, (w, h), borderValue=(114, 114, 114))

        # new name save
        new_stem = f"{src_stem}_aug{i}"
        cv2.imwrite(str(IMG_DIR / f"{new_stem}.jpg"), img)

        if src_lbl_path.exists():
            import shutil
            shutil.copy(src_lbl_path, LBL_DIR / f"{new_stem}.txt")

        aug_count += 1

print(f"augmented {aug_count} new images")

# final totals
final_images = len(list(IMG_DIR.glob('*.jpg')))
print(f"Dataset size: {total_images} → {final_images} images")
# Out:
# Class 0: 114 images
# Class 1: 104 images
# Class 2: 46 images
# Class 3: 100 images
# Class 4: 111 images
# Class 5: 102 images
# Class 6: 108 images
# Class 7: 104 images
# Class 8: 107 images
# Class 9: 107 images
# Class 10: 109 images
# Class 11: 108 images
# Class 12: 105 images
# Class 13: 127 images
# Class 14: 216 images
# Class 15: 106 images
# Class 16: 130 images
# Class 17: 117 images
# Class 18: 113 images
# Class 19: 103 images
# Class 158: 105 images
# Class 159: 100 images
# Class 160: 116 images
# Class 161: 109 images
# Class 162: 133 images
# Class 163: 97 images
# Class 164: 114 images
# Class 165: 105 images
# Class 166: 102 images
# Class 167: 136 images
# Class 168: 111 images
# Class 169: 114 images
# Class 170: 98 images
# Class 171: 109 images
# Class 172: 117 images
# Class 173: 100 images
# Class 174: 114 images
# Class 175: 101 images
# Class 176: 115 images
# Class 177: 104 images
# Class 178: 303 images
# Class 179: 112 images
# Class 180: 340 images
# Class 181: 85 images
# Class 182: 117 images
# Class 183: 106 images
# Class 184: 116 images
# Class 185: 100 images
# Class 186: 103 images
# Class 187: 106 images
# Class 188: 116 images
# Class 189: 106 images
# Class 190: 98 images
# Class 191: 119 images
# Class 192: 107 images
# Class 193: 157 images
# Class 194: 122 images
# Class 195: 130 images
# Class 196: 108 images
# Class 197: 98 images
# Class 198: 105 images
# Class 199: 103 images
# Class 200: 101 images
# Class 201: 105 images
# Class 202: 103 images
# Class 203: 97 images
# Class 204: 107 images
# Class 205: 106 images
# Class 206: 114 images
# Class 207: 101 images
# Class 208: 148 images
# Class 209: 106 images
# Class 210: 142 images
# Class 211: 117 images
# Class 212: 107 images
# Class 213: 101 images
# Class 214: 105 images
# Class 215: 103 images
# Class 216: 104 images
# Class 217: 108 images
# Class 218: 100 images
# Class 219: 115 images
# Class 220: 103 images
# Class 221: 104 images
# Class 222: 100 images
# Class 223: 101 images
# Class 224: 108 images
# Class 225: 106 images
# Class 226: 145 images
# Class 227: 108 images
# Class 228: 91 images
# Class 229: 106 images
# Class 230: 134 images
# Class 231: 109 images
# Class 232: 106 images
# Class 233: 120 images
# Class 234: 111 images
# Class 235: 107 images
# Class 236: 91 images
# Class 237: 119 images
# Class 238: 110 images
# Class 239: 115 images
# Class 240: 102 images
# Class 241: 200 images
# Class 242: 102 images
# Class 243: 103 images
# Class 244: 113 images
# Class 245: 138 images
# Class 246: 106 images
# Class 247: 95 images
# Class 248: 102 images
# Class 249: 116 images
# Class 250: 118 images
# Class 251: 113 images
# Class 252: 108 images
# Class 253: 104 images
# Class 254: 113 images
# Class 255: 110 images
# Class 256: 116 images
# median: 98 images
#   Class 141: removed 5 (target was 5)
#   Class 95: removed 3 (target was 3)
#   Class 178: removed 175 (target was 175)
#   Class 65: removed 71 (target was 71)
#   Class 22: removed 9 (target was 9)
#   Class 57: removed 12 (target was 12)
#   Class 226: removed 33 (target was 33)
#   Class 74: removed 11 (target was 11)
#   Class 171: removed 1 (target was 1)
#   Class 193: removed 44 (target was 44)
#   Class 130: removed 2 (target was 2)
#   Class 155: removed 9 (target was 9)
#   Class 42: removed 4 (target was 4)
#   Class 180: removed 208 (target was 208)
#   Class 50: removed 1 (target was 1)
#   Class 49: removed 7 (target was 7)
#   Class 169: removed 5 (target was 5)
#   Class 237: removed 10 (target was 10)
#   Class 230: removed 23 (target was 23)
#   Class 147: removed 8 (target was 8)
#   Class 62: removed 14 (target was 14)
#   Class 254: removed 4 (target was 4)
#   Class 97: removed 83 (target was 83)
#   Class 78: removed 7 (target was 7)
#   Class 233: removed 10 (target was 10)
#   Class 136: removed 2 (target was 2)
#   Class 106: removed 23 (target was 23)
#   Class 137: removed 4 (target was 4)
#   Class 66: removed 4 (target was 4)
#   Class 234: removed 2 (target was 2)
#   Class 52: removed 4 (target was 4)
#   Class 21: removed 2 (target was 2)
#   Class 167: removed 25 (target was 25)
#   Class 208: removed 36 (target was 36)
#   Class 103: removed 4 (target was 4)
#   Class 40: removed 7 (target was 7)
#   Class 162: removed 22 (target was 22)
#   Class 14: removed 97 (target was 97)
#   Class 83: removed 1 (target was 1)
#   Class 172: removed 8 (target was 8)
#   Class 256: removed 7 (target was 7)
#   Class 18: removed 4 (target was 4)
#   Class 59: removed 3 (target was 3)
#   Class 245: removed 27 (target was 27)
#   Class 56: removed 1 (target was 1)
#   Class 35: removed 5 (target was 5)
#   Class 211: removed 8 (target was 8)
#   Class 63: removed 1 (target was 1)
#   Class 219: removed 6 (target was 6)
#   Class 132: removed 219 (target was 219)
#   Class 255: removed 1 (target was 1)
#   Class 13: removed 17 (target was 17)
#   Class 122: removed 2 (target was 2)
#   Class 194: removed 12 (target was 12)
#   Class 104: removed 1 (target was 1)
#   Class 54: removed 25 (target was 25)
#   Class 68: removed 9 (target was 9)
#   Class 43: removed 1 (target was 1)
#   Class 206: removed 5 (target was 5)
#   Class 123: removed 1 (target was 1)
#   Class 184: removed 7 (target was 7)
#   Class 188: removed 7 (target was 7)
#   Class 70: removed 5 (target was 5)
#   Class 38: removed 24 (target was 24)
#   Class 10: removed 1 (target was 1)
#   Class 249: removed 7 (target was 7)
#   Class 250: removed 9 (target was 9)
#   Class 108: removed 19 (target was 19)
#   Class 16: removed 19 (target was 19)
#   Class 51: removed 2 (target was 2)
#   Class 118: removed 1 (target was 1)
#   Class 168: removed 2 (target was 2)
#   Class 231: removed 1 (target was 1)
#   Class 100: removed 8 (target was 8)
#   Class 161: removed 1 (target was 1)
#   Class 152: removed 7 (target was 7)
#   Class 67: removed 1 (target was 1)
#   Class 4: removed 2 (target was 2)
#   Class 37: removed 21 (target was 21)
#   Class 182: removed 8 (target was 8)
#   Class 31: removed 10 (target was 10)
#   Class 29: removed 4 (target was 4)
#   Class 241: removed 82 (target was 82)
#   Class 77: removed 16 (target was 16)
#   Class 238: removed 1 (target was 1)
#   Class 96: removed 1 (target was 1)
#   Class 114: removed 2 (target was 2)
#   Class 69: removed 10 (target was 10)
#   Class 151: removed 3 (target was 3)
#   Class 44: removed 1 (target was 1)
#   Class 244: removed 4 (target was 4)
#   Class 58: removed 6 (target was 6)
#   Class 239: removed 6 (target was 6)
#   Class 191: removed 10 (target was 10)
#   Class 125: removed 2 (target was 2)
#   Class 179: removed 3 (target was 3)
#   Class 145: removed 20 (target was 20)
#   Class 23: removed 4 (target was 4)
#   Class 251: removed 4 (target was 4)
#   Class 80: removed 36 (target was 36)
#   Class 0: removed 5 (target was 5)
#   Class 160: removed 7 (target was 7)
#   Class 92: removed 46 (target was 46)
#   Class 210: removed 30 (target was 30)
#   Class 176: removed 6 (target was 6)
#   Class 164: removed 5 (target was 5)
#   Class 117: removed 6 (target was 6)
#   Class 45: removed 12 (target was 12)
#   Class 88: removed 7 (target was 7)
#   Class 30: removed 3 (target was 3)
#   Class 174: removed 5 (target was 5)
#   Class 111: removed 3 (target was 3)
#   Class 85: removed 5 (target was 5)
#   Class 112: removed 9 (target was 9)
#   Class 90: removed 63 (target was 63)
#   Class 139: removed 1 (target was 1)
#   Class 17: removed 8 (target was 8)
#   Class 41: removed 6 (target was 6)
#   Class 79: removed 3 (target was 3)
#   Class 195: removed 19 (target was 19)
#   Class 199: augmenting 5 images from 93 originals
#   Class 36: augmenting 6 images from 92 originals
#   Class 148: augmenting 1 images from 97 originals
#   Class 198: augmenting 3 images from 95 originals
#   Class 166: augmenting 6 images from 92 originals
#   Class 99: augmenting 2 images from 96 originals
#   Class 71: augmenting 6 images from 92 originals
#   Class 9: augmenting 1 images from 97 originals
#   Class 131: augmenting 4 images from 94 originals
#   Class 225: augmenting 2 images from 96 originals
#   Class 8: augmenting 1 images from 97 originals
#   Class 186: augmenting 5 images from 93 originals
#   Class 157: augmenting 3 images from 95 originals
#   Class 228: augmenting 16 images from 82 originals
#   Class 15: augmenting 2 images from 96 originals
#   Class 109: augmenting 1 images from 97 originals
#   Class 94: augmenting 11 images from 87 originals
#   Class 165: augmenting 3 images from 95 originals
#   Class 39: augmenting 8 images from 90 originals
#   Class 223: augmenting 7 images from 91 originals
#   Class 215: augmenting 5 images from 93 originals
#   Class 1: augmenting 4 images from 94 originals
#   Class 105: augmenting 1 images from 97 originals
#   Class 101: augmenting 16 images from 82 originals
#   Class 170: augmenting 9 images from 89 originals
#   Class 126: augmenting 5 images from 93 originals
#   Class 204: augmenting 1 images from 97 originals
#   Class 242: augmenting 6 images from 92 originals
#   Class 26: augmenting 2 images from 96 originals
#   Class 115: augmenting 6 images from 92 originals
#   Class 84: augmenting 5 images from 93 originals
#   Class 64: augmenting 4 images from 94 originals
#   Class 213: augmenting 7 images from 91 originals
#   Class 163: augmenting 10 images from 88 originals
#   Class 133: augmenting 3 images from 95 originals
#   Class 60: augmenting 9 images from 89 originals
#   Class 175: augmenting 7 images from 91 originals
#   Class 110: augmenting 7 images from 91 originals
#   Class 107: augmenting 21 images from 77 originals
#   Class 202: augmenting 5 images from 93 originals
#   Class 33: augmenting 4 images from 94 originals
#   Class 216: augmenting 4 images from 94 originals
#   Class 158: augmenting 3 images from 95 originals
#   Class 7: augmenting 4 images from 94 originals
#   Class 113: augmenting 16 images from 82 originals
#   Class 72: augmenting 9 images from 89 originals
#   Class 134: augmenting 5 images from 93 originals
#   Class 240: augmenting 6 images from 92 originals
#   Class 146: augmenting 10 images from 88 originals
#   Class 212: augmenting 1 images from 97 originals
#   Class 183: augmenting 2 images from 96 originals
#   Class 127: augmenting 8 images from 90 originals
#   Class 190: augmenting 9 images from 89 originals
#   Class 32: augmenting 6 images from 92 originals
#   Class 253: augmenting 4 images from 94 originals
#   Class 124: augmenting 8 images from 90 originals
#   Class 177: augmenting 4 images from 94 originals
#   Class 5: augmenting 6 images from 92 originals
#   Class 222: augmenting 8 images from 90 originals
#   Class 19: augmenting 5 images from 93 originals
#   Class 91: augmenting 8 images from 90 originals
#   Class 75: augmenting 5 images from 93 originals
#   Class 46: augmenting 7 images from 91 originals
#   Class 229: augmenting 2 images from 96 originals
#   Class 187: augmenting 2 images from 96 originals
#   Class 76: augmenting 7 images from 91 originals
#   Class 102: augmenting 1 images from 97 originals
#   Class 144: augmenting 3 images from 95 originals
#   Class 25: augmenting 3 images from 95 originals
#   Class 221: augmenting 4 images from 94 originals
#   Class 119: augmenting 4 images from 94 originals
#   Class 200: augmenting 7 images from 91 originals
#   Class 27: augmenting 4 images from 94 originals
#   Class 201: augmenting 3 images from 95 originals
#   Class 173: augmenting 8 images from 90 originals
#   Class 243: augmenting 5 images from 93 originals
#   Class 197: augmenting 9 images from 89 originals
#   Class 129: augmenting 4 images from 94 originals
#   Class 34: augmenting 7 images from 91 originals
#   Class 192: augmenting 1 images from 97 originals
#   Class 135: augmenting 8 images from 90 originals
#   Class 93: augmenting 5 images from 93 originals
#   Class 89: augmenting 8 images from 90 originals
#   Class 53: augmenting 8 images from 90 originals
#   Class 3: augmenting 8 images from 90 originals
#   Class 203: augmenting 10 images from 88 originals
#   Class 73: augmenting 6 images from 92 originals
#   Class 205: augmenting 2 images from 96 originals
#   Class 2: augmenting 56 images from 42 originals
#   Class 247: augmenting 12 images from 86 originals
#   Class 185: augmenting 8 images from 90 originals
#   Class 236: augmenting 16 images from 82 originals
#   Class 246: augmenting 2 images from 96 originals
#   Class 48: augmenting 8 images from 90 originals
#   Class 156: augmenting 6 images from 92 originals
#   Class 55: augmenting 4 images from 94 originals
#   Class 209: augmenting 2 images from 96 originals
#   Class 86: augmenting 5 images from 93 originals
#   Class 81: augmenting 2 images from 96 originals
#   Class 214: augmenting 3 images from 95 originals
#   Class 143: augmenting 2 images from 96 originals
#   Class 235: augmenting 1 images from 97 originals
#   Class 181: augmenting 21 images from 77 originals
#   Class 248: augmenting 6 images from 92 originals
#   Class 218: augmenting 8 images from 90 originals
#   Class 98: augmenting 7 images from 91 originals
#   Class 28: augmenting 3 images from 95 originals
#   Class 12: augmenting 3 images from 95 originals
#   Class 232: augmenting 2 images from 96 originals
#   Class 116: augmenting 6 images from 92 originals
#   Class 150: augmenting 7 images from 91 originals
#   Class 87: augmenting 11 images from 87 originals
#   Class 220: augmenting 5 images from 93 originals
#   Class 138: augmenting 4 images from 94 originals
#   Class 128: augmenting 8 images from 90 originals
#   Class 61: augmenting 7 images from 91 originals
#   Class 189: augmenting 2 images from 96 originals
#   Class 207: augmenting 7 images from 91 originals
#   Class 140: augmenting 6 images from 92 originals
#   Class 159: augmenting 8 images from 90 originals
#   Class 82: augmenting 4 images from 94 originals
#   Class 121: augmenting 9 images from 89 originals
#   Class 153: augmenting 43 images from 55 originals
#   Class 20: augmenting 5 images from 93 originals
# augmented 806 new images
# Dataset size: 29167 → 25186 images

# %%
import supervision as sv
from pathlib import Path

ds = sv.DetectionDataset.from_yolo(
    images_directory_path=str(new_img_dir),
    annotations_directory_path=str(new_label_dir),
    data_yaml_path=str(dir / 'data.yaml')
)

seed = 1
train_ds, rest_ds = ds.split(split_ratio=0.8, random_state=seed, shuffle=True)
test_ds, val_ds = rest_ds.split(split_ratio=0.5, random_state=seed, shuffle=True)

# save splits in yolo format
train_ds.as_yolo(
    images_directory_path=str(split_path / 'train' / 'images'),
    annotations_directory_path=str(split_path / 'train' / 'labels'),
    data_yaml_path=str(split_path / 'train' / 'data.yaml')
)
test_ds.as_yolo(
    images_directory_path=str(split_path / 'test' / 'images'),
    annotations_directory_path=str(split_path / 'test' / 'labels'),
    data_yaml_path=str(split_path / 'test' / 'data.yaml')
)
val_ds.as_yolo(
    images_directory_path=str(split_path / 'valid' / 'images'),
    annotations_directory_path=str(split_path / 'valid' / 'labels'),
    data_yaml_path=str(split_path / 'valid' / 'data.yaml')
)

def write_manifest(ds: sv.DetectionDataset, split: str, output_path: Path):
    with open(output_path, "w") as f:
        for img_path, _, _ in ds:
            f.write(f"{str(Path(img_path).name)}\n")
    print(f"Wrote to {output_path}")

write_manifest(train_ds, "train", Path(split_path) / "train.txt")
write_manifest(test_ds, "test", Path(split_path) / "test.txt")
write_manifest(val_ds, "valid", Path(split_path) / "valid.txt")

# count images per split
import glob, os
for root, dirs, files in os.walk("/content/split", topdown=True):
    if os.path.basename(root) == "images":
        imgs = glob.glob(os.path.join(root, "*.jpg"))
        print(f"{root} -> {len(imgs)} images")
# Out:
# Wrote to /content/split/train.txt
# Wrote to /content/split/test.txt
# Wrote to /content/split/valid.txt
# /content/split/valid/images -> 2519 images
# /content/split/train/images -> 20148 images
# /content/split/test/images -> 2519 images

# %%
# %pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.21-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.25.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.8.0->ultralytics) (1.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.21-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 79.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.21 ultralytics-thop-2.0.18

# %%
from pathlib import Path
from collections import Counter

def count_images_per_class(labels_dir, class_names):
    labels_dir = Path(labels_dir)
    image_count_per_class = Counter()

    for lbl_file in labels_dir.glob('*.txt'):
        with lbl_file.open() as f:
            classes_in_image = set(int(line.split()[0]) for line in f if line.strip())
        for cls_id in classes_in_image:
            image_count_per_class[cls_id] += 1

    print(f"Class distribution in {labels_dir.parent.name}:")
    print("-" * 60)
    for cls_id in range(len(class_names)):
        count = image_count_per_class.get(cls_id, 0)
        print(f"{cls_id:2d} {class_names[cls_id]:30s}: {count:4d} images")
    print("-" * 60)
    return image_count_per_class

train_labels = split_path / 'train' / 'labels'
valid_labels = split_path / 'valid' / 'labels'
test_labels = split_path / 'test' / 'labels'

# Load class names
class_names = ds.classes

# Count distribution
train_counts = count_images_per_class(train_labels, class_names)
valid_counts = count_images_per_class(valid_labels, class_names)
test_counts = count_images_per_class(test_labels, class_names)
# Out:
# Class distribution in train:
# ------------------------------------------------------------
#  0 adobo                         :   86 images
#  1 almond-jelly                  :   82 images
#  2 apple                         :   78 images
#  3 apple-pie                     :   86 images
#  4 ayam-bakar                    :   76 images
#  5 ayam-goreng                   :   83 images
#  6 babi-guling                   :   89 images
#  7 bagel                         :   75 images
#  8 bak-kut-teh                   :   76 images
#  9 baked-salmon                  :   86 images
# 10 ball-shaped-bun-with-pork     :   72 images
# 11 barbecued-red-pork-in-sauce-with-rice:   77 images
# 12 bean-curd-family-style        :   77 images
# 13 beef-bowl                     :   76 images
# 14 beef-curry                    :   79 images
# 15 beef-in-oyster-sauce          :   81 images
# 16 beef-noodle                   :   79 images
# 17 beef-noodle-soup              :   74 images
# 18 bibimbap                      :   79 images
# 19 boiled-chicken-and-vegetables :   73 images
# 20 boiled-fish                   :   78 images
# 21 boned-sliced-hainan-style-chicken-with-marinated-rice:   73 images
# 22 braised-pork-meat-ball-with-napa-cabbage:   77 images
# 23 broiled-eel-bowl              :   86 images
# 24 brownie                       :   81 images
# 25 bubur-ayam                    :   73 images
# 26 cabbage-roll                  :   79 images
# 27 caesar-salad                  :   77 images
# 28 champon                       :   78 images
# 29 charcoal-boiled-pork-neck     :   74 images
# 30 chicken-cutlet                :   80 images
# 31 chicken-n-egg-on-rice         :   79 images
# 32 chicken-nugget                :   80 images
# 33 chicken-rice                  :   75 images
# 34 chicken-rice-curry-with-coconut:   87 images
# 35 chilled-noodle                :   78 images
# 36 chinese-pumpkin-pie           :   79 images
# 37 chinese-soup                  :   79 images
# 38 chip-butty                    :   79 images
# 39 chop-suey                     :   74 images
# 40 chow-mein                     :   86 images
# 41 churro                        :   79 images
# 42 clear-soup                    :   83 images
# 43 coconut-milk-flavored-crepes-with-shrimp-and-beef:   77 images
# 44 coconut-milk-soup             :   78 images
# 45 cold-tofu                     :   79 images
# 46 crape                         :   79 images
# 47 cream-puff                    :   88 images
# 48 crispy-noodles                :   82 images
# 49 croissant                     :   83 images
# 50 croquette                     :   81 images
# 51 crullers                      :   78 images
# 52 curry-puff                    :   76 images
# 53 custard-tart                  :   76 images
# 54 cutlet-curry                  :   77 images
# 55 dak-galbi                     :   81 images
# 56 deep-fried-chicken-wing       :   77 images
# 57 dipping-noodles               :   75 images
# 58 dish-consisting-of-stir-fried-potato-eggplant-and-green-pepper:   78 images
# 59 doughnut                      :   81 images
# 60 dried-fish                    :   77 images
# 61 dry-curry                     :   84 images
# 62 eels-on-rice                  :   79 images
# 63 egg-noodle-in-chicken-yellow-curry:   76 images
# 64 egg-roll                      :   85 images
# 65 egg-sunny-side-up             :   86 images
# 66 eggplant-with-garlic-sauce    :   78 images
# 67 eight-treasure-rice           :   83 images
# 68 fine-white-noodles            :   76 images
# 69 fish-ball-soup                :   82 images
# 70 fish-shaped-pancake-with-bean-jam:   81 images
# 71 french-bread                  :   72 images
# 72 french-fries                  :   82 images
# 73 french-toast                  :   80 images
# 74 fried-chicken                 :   82 images
# 75 fried-fish                    :   74 images
# 76 fried-mussel-pancakes         :   78 images
# 77 fried-noodle                  :   81 images
# 78 fried-pork-dumplings-served-in-soup:   81 images
# 79 fried-pork-in-scoop           :   75 images
# 80 fried-rice                    :   78 images
# 81 fried-shrimp                  :   81 images
# 82 fried-spring-rolls            :   79 images
# 83 ganmodoki                     :   77 images
# 84 ginger-pork-saute             :   77 images
# 85 glutinous-oil-rice            :   79 images
# 86 glutinous-rice-balls          :   79 images
# 87 goya-chanpuru                 :   86 images
# 88 gratin                        :   83 images
# 89 green-curry                   :   77 images
# 90 green-salad                   :   86 images
# 91 grilled-eggplant              :   82 images
# 92 grilled-pacific-saury         :   74 images
# 93 grilled-salmon                :   78 images
# 94 gulai                         :   79 images
# 95 ham-cutlet                    :   75 images
# 96 hambarg-steak                 :   75 images
# 97 hamburger                     :   80 images
# 98 haupia                        :   73 images
# 99 hot-and-sour-fish-and-vegetable-ragout:   76 images
# 100 hot-and-sour-soup             :   77 images
# 101 hot-dog                       :   75 images
# 102 hot-pot                       :   75 images
# 103 hue-beef-rice-vermicelli-soup :   82 images
# 104 inarizushi                    :   83 images
# 105 jambalaya                     :   81 images
# 106 japanese-style-pancake        :   72 images
# 107 japanese-tofu-and-vegetable-chowder:   81 images
# 108 jiaozi                        :   82 images
# 109 jjigae                        :   87 images
# 110 kamameshi                     :   79 images
# 111 kaya-toast                    :   86 images
# 112 khao-soi                      :   80 images
# 113 kinpira-style-sauteed-burdock :   72 images
# 114 kung-pao-chicken              :   73 images
# 115 kushikatu                     :   81 images
# 116 laksa                         :   80 images
# 117 lamb-kebabs                   :   77 images
# 118 lasagna                       :   74 images
# 119 laulau                        :   74 images
# 120 lemon-fig-jelly               :   79 images
# 121 lightly-roasted-fish          :   76 images
# 122 loco-moco                     :   78 images
# 123 lumpia                        :   78 images
# 124 macaroni-salad                :   84 images
# 125 malasada                      :   76 images
# 126 mango-pudding                 :   75 images
# 127 mie-ayam                      :   74 images
# 128 mie-goreng                    :   84 images
# 129 minced-meat-cutlet            :   80 images
# 130 minced-pork-rice              :   82 images
# 131 minestrone                    :   71 images
# 132 miso-soup                     :   83 images
# 133 mixed-rice                    :   77 images
# 134 moon-cake                     :   78 images
# 135 mozuku                        :   84 images
# 136 muffin                        :   78 images
# 137 mushroom-risotto              :   80 images
# 138 nachos                        :   81 images
# 139 namero                        :   85 images
# 140 nanbanzuke                    :   70 images
# 141 nasi-campur                   :   77 images
# 142 nasi-goreng                   :   79 images
# 143 nasi-padang                   :   73 images
# 144 nasi-uduk                     :   73 images
# 145 natto                         :   76 images
# 146 noodles-with-fish-curry       :   82 images
# 147 oatmeal                       :   81 images
# 148 oden                          :   81 images
# 149 okinawa-soba                  :   79 images
# 150 omelet                        :   77 images
# 151 omelet-40                     :   72 images
# 152 omelet-with-fried-rice        :   77 images
# 153 orange                        :   78 images
# 154 oshiruko                      :   74 images
# 155 oxtail-soup                   :   78 images
# 156 oyster-omelette               :   79 images
# 157 paella                        :   75 images
# 158 pancake                       :   78 images
# 159 parfait                       :   73 images
# 160 pho                           :   65 images
# 161 pilaf                         :   76 images
# 162 pizza                         :   76 images
# 163 pizza-toast                   :   78 images
# 164 popcorn                       :   78 images
# 165 pork-belly                    :   72 images
# 166 pork-cutlet                   :   75 images
# 167 pork-cutlet-on-rice           :   79 images
# 168 pork-fillet-cutlet            :   81 images
# 169 pork-loin-cutlet              :   83 images
# 170 pork-miso-soup                :   80 images
# 171 pork-satay                    :   74 images
# 172 pork-sticky-noodles           :   76 images
# 173 pork-with-lemon               :   79 images
# 174 pot-au-feu                    :   81 images
# 175 potage                        :   72 images
# 176 potato-salad                  :   81 images
# 177 raisin-bread                  :   78 images
# 178 ramen-noodle                  :   80 images
# 179 rare-cheese-cake              :   72 images
# 180 rice                          :   82 images
# 181 rice-ball                     :   82 images
# 182 rice-crispy-pork              :   82 images
# 183 rice-gratin                   :   77 images
# 184 rice-gruel                    :   75 images
# 185 rice-vermicelli               :   78 images
# 186 rice-with-roast-duck          :   80 images
# 187 roast-chicken                 :   71 images
# 188 roast-duck                    :   81 images
# 189 roll-bread                    :   77 images
# 190 salmon-meuniere               :   77 images
# 191 salt-and-pepper-fried-shrimp-with-shell:   75 images
# 192 samul                         :   78 images
# 193 sandwiches                    :   79 images
# 194 sashimi                       :   82 images
# 195 sashimi-bowl                  :   68 images
# 196 sausage                       :   77 images
# 197 sauteed-spinach               :   75 images
# 198 sauteed-vegetables            :   81 images
# 199 scone                         :   72 images
# 200 scrambled-egg                 :   77 images
# 201 seasoned-beef-with-potatoes   :   80 images
# 202 shortcake                     :   78 images
# 203 shrimp-patties                :   77 images
# 204 shrimp-with-chill-source      :   76 images
# 205 simmered-pork                 :   75 images
# 206 sirloin-cutlet                :   74 images
# 207 small-steamed-savory-rice-pancake:   77 images
# 208 soba-noodle                   :   78 images
# 209 sour-prawn-soup               :   80 images
# 210 spaghetti                     :   82 images
# 211 spaghetti-meat-sauce          :   83 images
# 212 spam-musubi                   :   84 images
# 213 spicy-chicken-salad           :   84 images
# 214 spicy-chili-flavored-tofu     :   84 images
# 215 steak                         :   75 images
# 216 steamed-egg-hotchpotch        :   80 images
# 217 steamed-meat-dumpling         :   77 images
# 218 steamed-rice-roll             :   85 images
# 219 steamed-spareribs             :   80 images
# 220 stew                          :   80 images
# 221 stewed-pork-leg               :   76 images
# 222 stinky-tofu                   :   78 images
# 223 stir-fried-beef-and-peppers   :   75 images
# 224 stir-fried-mixed-vegetables   :   69 images
# 225 sukiyaki                      :   74 images
# 226 sushi                         :   78 images
# 227 sushi-bowl                    :   75 images
# 228 sweet-and-sour-pork           :   79 images
# 229 tacos                         :   81 images
# 230 takoyaki                      :   79 images
# 231 tanmen                        :   80 images
# 232 tempura                       :   81 images
# 233 tempura-bowl                  :   75 images
# 234 tempura-udon                  :   83 images
# 235 tensin-noodle                 :   78 images
# 236 teriyaki-grilled-fish         :   80 images
# 237 thai-papaya-salad             :   76 images
# 238 thinly-sliced-raw-horsemeat   :   75 images
# 239 three-cup-chicken             :   75 images
# 240 tiramisu                      :   74 images
# 241 toast                         :   73 images
# 242 tortilla                      :   76 images
# 243 trunip-pudding                :   80 images
# 244 twice-cooked-pork             :   83 images
# 245 udon-noodle                   :   75 images
# 246 vegetable-tempura             :   78 images
# 247 vermicelli-noodles-with-snails:   73 images
# 248 waffle                        :   77 images
# 249 winter-melon-soup             :   80 images
# 250 wonton-soup                   :   76 images
# 251 xiao-long-bao                 :   83 images
# 252 yakitori                      :   82 images
# 253 yellow-curry                  :   84 images
# 254 yudofu                        :   79 images
# 255 zha-jiang-mian                :   82 images
# 256 zoni                          :   79 images
# ------------------------------------------------------------
# Class distribution in valid:
# ------------------------------------------------------------
#  0 adobo                         :    7 images
#  1 almond-jelly                  :    9 images
#  2 apple                         :    7 images
#  3 apple-pie                     :    7 images
#  4 ayam-bakar                    :   11 images
#  5 ayam-goreng                   :    8 images
#  6 babi-guling                   :    6 images
#  7 bagel                         :   10 images
#  8 bak-kut-teh                   :   11 images
#  9 baked-salmon                  :    3 images
# 10 ball-shaped-bun-with-pork     :   13 images
# 11 barbecued-red-pork-in-sauce-with-rice:   11 images
# 12 bean-curd-family-style        :   14 images
# 13 beef-bowl                     :   10 images
# 14 beef-curry                    :    6 images
# 15 beef-in-oyster-sauce          :   10 images
# 16 beef-noodle                   :   11 images
# 17 beef-noodle-soup              :   10 images
# 18 bibimbap                      :    8 images
# 19 boiled-chicken-and-vegetables :   12 images
# 20 boiled-fish                   :   14 images
# 21 boned-sliced-hainan-style-chicken-with-marinated-rice:   10 images
# 22 braised-pork-meat-ball-with-napa-cabbage:    8 images
# 23 broiled-eel-bowl              :   10 images
# 24 brownie                       :    8 images
# 25 bubur-ayam                    :   13 images
# 26 cabbage-roll                  :    8 images
# 27 caesar-salad                  :   12 images
# 28 champon                       :   12 images
# 29 charcoal-boiled-pork-neck     :   12 images
# 30 chicken-cutlet                :   10 images
# 31 chicken-n-egg-on-rice         :   10 images
# 32 chicken-nugget                :    7 images
# 33 chicken-rice                  :   14 images
# 34 chicken-rice-curry-with-coconut:    8 images
# 35 chilled-noodle                :    8 images
# 36 chinese-pumpkin-pie           :    6 images
# 37 chinese-soup                  :   12 images
# 38 chip-butty                    :   13 images
# 39 chop-suey                     :   11 images
# 40 chow-mein                     :    3 images
# 41 churro                        :    7 images
# 42 clear-soup                    :   10 images
# 43 coconut-milk-flavored-crepes-with-shrimp-and-beef:   12 images
# 44 coconut-milk-soup             :    9 images
# 45 cold-tofu                     :    7 images
# 46 crape                         :   10 images
# 47 cream-puff                    :    2 images
# 48 crispy-noodles                :   11 images
# 49 croissant                     :    9 images
# 50 croquette                     :    5 images
# 51 crullers                      :   15 images
# 52 curry-puff                    :   13 images
# 53 custard-tart                  :   11 images
# 54 cutlet-curry                  :   10 images
# 55 dak-galbi                     :    5 images
# 56 deep-fried-chicken-wing       :   10 images
# 57 dipping-noodles               :    6 images
# 58 dish-consisting-of-stir-fried-potato-eggplant-and-green-pepper:    6 images
# 59 doughnut                      :    9 images
# 60 dried-fish                    :    9 images
# 61 dry-curry                     :    5 images
# 62 eels-on-rice                  :   11 images
# 63 egg-noodle-in-chicken-yellow-curry:   11 images
# 64 egg-roll                      :    6 images
# 65 egg-sunny-side-up             :    8 images
# 66 eggplant-with-garlic-sauce    :   10 images
# 67 eight-treasure-rice           :    8 images
# 68 fine-white-noodles            :   13 images
# 69 fish-ball-soup                :   12 images
# 70 fish-shaped-pancake-with-bean-jam:    9 images
# 71 french-bread                  :   11 images
# 72 french-fries                  :    8 images
# 73 french-toast                  :    6 images
# 74 fried-chicken                 :    7 images
# 75 fried-fish                    :    7 images
# 76 fried-mussel-pancakes         :   15 images
# 77 fried-noodle                  :    9 images
# 78 fried-pork-dumplings-served-in-soup:   11 images
# 79 fried-pork-in-scoop           :   10 images
# 80 fried-rice                    :    9 images
# 81 fried-shrimp                  :   10 images
# 82 fried-spring-rolls            :    9 images
# 83 ganmodoki                     :   10 images
# 84 ginger-pork-saute             :    9 images
# 85 glutinous-oil-rice            :    9 images
# 86 glutinous-rice-balls          :    8 images
# 87 goya-chanpuru                 :    3 images
# 88 gratin                        :    4 images
# 89 green-curry                   :   17 images
# 90 green-salad                   :    8 images
# 91 grilled-eggplant              :    9 images
# 92 grilled-pacific-saury         :   10 images
# 93 grilled-salmon                :   13 images
# 94 gulai                         :    7 images
# 95 ham-cutlet                    :    9 images
# 96 hambarg-steak                 :   10 images
# 97 hamburger                     :    9 images
# 98 haupia                        :   12 images
# 99 hot-and-sour-fish-and-vegetable-ragout:   12 images
# 100 hot-and-sour-soup             :   10 images
# 101 hot-dog                       :    9 images
# 102 hot-pot                       :   12 images
# 103 hue-beef-rice-vermicelli-soup :    6 images
# 104 inarizushi                    :    6 images
# 105 jambalaya                     :    6 images
# 106 japanese-style-pancake        :   13 images
# 107 japanese-tofu-and-vegetable-chowder:   11 images
# 108 jiaozi                        :    8 images
# 109 jjigae                        :    6 images
# 110 kamameshi                     :    9 images
# 111 kaya-toast                    :    5 images
# 112 khao-soi                      :   11 images
# 113 kinpira-style-sauteed-burdock :   18 images
# 114 kung-pao-chicken              :    7 images
# 115 kushikatu                     :    9 images
# 116 laksa                         :    8 images
# 117 lamb-kebabs                   :   11 images
# 118 lasagna                       :   14 images
# 119 laulau                        :   13 images
# 120 lemon-fig-jelly               :    9 images
# 121 lightly-roasted-fish          :   15 images
# 122 loco-moco                     :   11 images
# 123 lumpia                        :   11 images
# 124 macaroni-salad                :    8 images
# 125 malasada                      :    9 images
# 126 mango-pudding                 :   17 images
# 127 mie-ayam                      :   10 images
# 128 mie-goreng                    :    6 images
# 129 minced-meat-cutlet            :    9 images
# 130 minced-pork-rice              :    6 images
# 131 minestrone                    :   16 images
# 132 miso-soup                     :    8 images
# 133 mixed-rice                    :   11 images
# 134 moon-cake                     :   12 images
# 135 mozuku                        :    7 images
# 136 muffin                        :    9 images
# 137 mushroom-risotto              :   10 images
# 138 nachos                        :    8 images
# 139 namero                        :    8 images
# 140 nanbanzuke                    :   16 images
# 141 nasi-campur                   :   10 images
# 142 nasi-goreng                   :    8 images
# 143 nasi-padang                   :   13 images
# 144 nasi-uduk                     :    8 images
# 145 natto                         :   10 images
# 146 noodles-with-fish-curry       :    8 images
# 147 oatmeal                       :    7 images
# 148 oden                          :    8 images
# 149 okinawa-soba                  :    8 images
# 150 omelet                        :   14 images
# 151 omelet-40                     :   12 images
# 152 omelet-with-fried-rice        :    8 images
# 153 orange                        :   12 images
# 154 oshiruko                      :   18 images
# 155 oxtail-soup                   :    9 images
# 156 oyster-omelette               :   13 images
# 157 paella                        :   13 images
# 158 pancake                       :   10 images
# 159 parfait                       :   13 images
# 160 pho                           :   17 images
# 161 pilaf                         :   12 images
# 162 pizza                         :   12 images
# 163 pizza-toast                   :    9 images
# 164 popcorn                       :    9 images
# 165 pork-belly                    :   14 images
# 166 pork-cutlet                   :   16 images
# 167 pork-cutlet-on-rice           :    7 images
# 168 pork-fillet-cutlet            :    6 images
# 169 pork-loin-cutlet              :    8 images
# 170 pork-miso-soup                :   10 images
# 171 pork-satay                    :   13 images
# 172 pork-sticky-noodles           :   13 images
# 173 pork-with-lemon               :   12 images
# 174 pot-au-feu                    :    6 images
# 175 potage                        :   17 images
# 176 potato-salad                  :   12 images
# 177 raisin-bread                  :    7 images
# 178 ramen-noodle                  :    7 images
# 179 rare-cheese-cake              :   17 images
# 180 rice                          :   10 images
# 181 rice-ball                     :    7 images
# 182 rice-crispy-pork              :    5 images
# 183 rice-gratin                   :    8 images
# 184 rice-gruel                    :    7 images
# 185 rice-vermicelli               :   14 images
# 186 rice-with-roast-duck          :    9 images
# 187 roast-chicken                 :   12 images
# 188 roast-duck                    :    7 images
# 189 roll-bread                    :   10 images
# 190 salmon-meuniere               :   10 images
# 191 salt-and-pepper-fried-shrimp-with-shell:   10 images
# 192 samul                         :    9 images
# 193 sandwiches                    :    7 images
# 194 sashimi                       :    5 images
# 195 sashimi-bowl                  :   15 images
# 196 sausage                       :   12 images
# 197 sauteed-spinach               :    8 images
# 198 sauteed-vegetables            :    9 images
# 199 scone                         :    6 images
# 200 scrambled-egg                 :    9 images
# 201 seasoned-beef-with-potatoes   :    7 images
# 202 shortcake                     :   16 images
# 203 shrimp-patties                :   12 images
# 204 shrimp-with-chill-source      :   10 images
# 205 simmered-pork                 :    8 images
# 206 sirloin-cutlet                :   13 images
# 207 small-steamed-savory-rice-pancake:   16 images
# 208 soba-noodle                   :    8 images
# 209 sour-prawn-soup               :   12 images
# 210 spaghetti                     :    8 images
# 211 spaghetti-meat-sauce          :    7 images
# 212 spam-musubi                   :    6 images
# 213 spicy-chicken-salad           :    6 images
# 214 spicy-chili-flavored-tofu     :    5 images
# 215 steak                         :   11 images
# 216 steamed-egg-hotchpotch        :   11 images
# 217 steamed-meat-dumpling         :   10 images
# 218 steamed-rice-roll             :    7 images
# 219 steamed-spareribs             :    9 images
# 220 stew                          :    8 images
# 221 stewed-pork-leg               :   11 images
# 222 stinky-tofu                   :   14 images
# 223 stir-fried-beef-and-peppers   :   10 images
# 224 stir-fried-mixed-vegetables   :   17 images
# 225 sukiyaki                      :   11 images
# 226 sushi                         :   13 images
# 227 sushi-bowl                    :   11 images
# 228 sweet-and-sour-pork           :    7 images
# 229 tacos                         :   11 images
# 230 takoyaki                      :    8 images
# 231 tanmen                        :    8 images
# 232 tempura                       :    8 images
# 233 tempura-bowl                  :    8 images
# 234 tempura-udon                  :    6 images
# 235 tensin-noodle                 :   13 images
# 236 teriyaki-grilled-fish         :   13 images
# 237 thai-papaya-salad             :    9 images
# 238 thinly-sliced-raw-horsemeat   :   12 images
# 239 three-cup-chicken             :   10 images
# 240 tiramisu                      :   14 images
# 241 toast                         :   14 images
# 242 tortilla                      :    7 images
# 243 trunip-pudding                :    9 images
# 244 twice-cooked-pork             :    8 images
# 245 udon-noodle                   :   13 images
# 246 vegetable-tempura             :    8 images
# 247 vermicelli-noodles-with-snails:   14 images
# 248 waffle                        :   11 images
# 249 winter-melon-soup             :   11 images
# 250 wonton-soup                   :    9 images
# 251 xiao-long-bao                 :    7 images
# 252 yakitori                      :    9 images
# 253 yellow-curry                  :    8 images
# 254 yudofu                        :   14 images
# 255 zha-jiang-mian                :   10 images
# 256 zoni                          :    7 images
# ------------------------------------------------------------
# Class distribution in test:
# ------------------------------------------------------------
#  0 adobo                         :    5 images
#  1 almond-jelly                  :    7 images
#  2 apple                         :   13 images
#  3 apple-pie                     :    5 images
#  4 ayam-bakar                    :   11 images
#  5 ayam-goreng                   :    7 images
#  6 babi-guling                   :    3 images
#  7 bagel                         :   13 images
#  8 bak-kut-teh                   :   11 images
#  9 baked-salmon                  :    9 images
# 10 ball-shaped-bun-with-pork     :   13 images
# 11 barbecued-red-pork-in-sauce-with-rice:   10 images
# 12 bean-curd-family-style        :    7 images
# 13 beef-bowl                     :   12 images
# 14 beef-curry                    :   13 images
# 15 beef-in-oyster-sauce          :    7 images
# 16 beef-noodle                   :    8 images
# 17 beef-noodle-soup              :   14 images
# 18 bibimbap                      :   11 images
# 19 boiled-chicken-and-vegetables :   13 images
# 20 boiled-fish                   :    6 images
# 21 boned-sliced-hainan-style-chicken-with-marinated-rice:   15 images
# 22 braised-pork-meat-ball-with-napa-cabbage:   13 images
# 23 broiled-eel-bowl              :    2 images
# 24 brownie                       :    9 images
# 25 bubur-ayam                    :   12 images
# 26 cabbage-roll                  :   11 images
# 27 caesar-salad                  :    9 images
# 28 champon                       :    8 images
# 29 charcoal-boiled-pork-neck     :   12 images
# 30 chicken-cutlet                :    8 images
# 31 chicken-n-egg-on-rice         :    9 images
# 32 chicken-nugget                :   11 images
# 33 chicken-rice                  :    9 images
# 34 chicken-rice-curry-with-coconut:    3 images
# 35 chilled-noodle                :   12 images
# 36 chinese-pumpkin-pie           :   13 images
# 37 chinese-soup                  :    7 images
# 38 chip-butty                    :    6 images
# 39 chop-suey                     :   13 images
# 40 chow-mein                     :    9 images
# 41 churro                        :   12 images
# 42 clear-soup                    :    5 images
# 43 coconut-milk-flavored-crepes-with-shrimp-and-beef:    9 images
# 44 coconut-milk-soup             :   11 images
# 45 cold-tofu                     :   12 images
# 46 crape                         :    9 images
# 47 cream-puff                    :    8 images
# 48 crispy-noodles                :    5 images
# 49 croissant                     :    6 images
# 50 croquette                     :   12 images
# 51 crullers                      :    5 images
# 52 curry-puff                    :    9 images
# 53 custard-tart                  :   11 images
# 54 cutlet-curry                  :   11 images
# 55 dak-galbi                     :   12 images
# 56 deep-fried-chicken-wing       :   11 images
# 57 dipping-noodles               :   17 images
# 58 dish-consisting-of-stir-fried-potato-eggplant-and-green-pepper:   14 images
# 59 doughnut                      :    8 images
# 60 dried-fish                    :   12 images
# 61 dry-curry                     :    9 images
# 62 eels-on-rice                  :    8 images
# 63 egg-noodle-in-chicken-yellow-curry:   11 images
# 64 egg-roll                      :    7 images
# 65 egg-sunny-side-up             :    4 images
# 66 eggplant-with-garlic-sauce    :   10 images
# 67 eight-treasure-rice           :    7 images
# 68 fine-white-noodles            :    9 images
# 69 fish-ball-soup                :    4 images
# 70 fish-shaped-pancake-with-bean-jam:    8 images
# 71 french-bread                  :   15 images
# 72 french-fries                  :    8 images
# 73 french-toast                  :   12 images
# 74 fried-chicken                 :    9 images
# 75 fried-fish                    :   17 images
# 76 fried-mussel-pancakes         :    5 images
# 77 fried-noodle                  :    8 images
# 78 fried-pork-dumplings-served-in-soup:    6 images
# 79 fried-pork-in-scoop           :   13 images
# 80 fried-rice                    :   11 images
# 81 fried-shrimp                  :    7 images
# 82 fried-spring-rolls            :   10 images
# 83 ganmodoki                     :   11 images
# 84 ginger-pork-saute             :   12 images
# 85 glutinous-oil-rice            :   10 images
# 86 glutinous-rice-balls          :   11 images
# 87 goya-chanpuru                 :    9 images
# 88 gratin                        :   11 images
# 89 green-curry                   :    4 images
# 90 green-salad                   :    4 images
# 91 grilled-eggplant              :    7 images
# 92 grilled-pacific-saury         :   14 images
# 93 grilled-salmon                :    7 images
# 94 gulai                         :   12 images
# 95 ham-cutlet                    :   14 images
# 96 hambarg-steak                 :   13 images
# 97 hamburger                     :    9 images
# 98 haupia                        :   13 images
# 99 hot-and-sour-fish-and-vegetable-ragout:   10 images
# 100 hot-and-sour-soup             :   11 images
# 101 hot-dog                       :   14 images
# 102 hot-pot                       :   11 images
# 103 hue-beef-rice-vermicelli-soup :   10 images
# 104 inarizushi                    :    9 images
# 105 jambalaya                     :   11 images
# 106 japanese-style-pancake        :   13 images
# 107 japanese-tofu-and-vegetable-chowder:    6 images
# 108 jiaozi                        :    8 images
# 109 jjigae                        :    5 images
# 110 kamameshi                     :   10 images
# 111 kaya-toast                    :    7 images
# 112 khao-soi                      :    7 images
# 113 kinpira-style-sauteed-burdock :    8 images
# 114 kung-pao-chicken              :   18 images
# 115 kushikatu                     :    8 images
# 116 laksa                         :   10 images
# 117 lamb-kebabs                   :   10 images
# 118 lasagna                       :   10 images
# 119 laulau                        :   11 images
# 120 lemon-fig-jelly               :   10 images
# 121 lightly-roasted-fish          :    7 images
# 122 loco-moco                     :    9 images
# 123 lumpia                        :    9 images
# 124 macaroni-salad                :    6 images
# 125 malasada                      :   13 images
# 126 mango-pudding                 :    6 images
# 127 mie-ayam                      :   14 images
# 128 mie-goreng                    :    8 images
# 129 minced-meat-cutlet            :    9 images
# 130 minced-pork-rice              :   10 images
# 131 minestrone                    :   11 images
# 132 miso-soup                     :    7 images
# 133 mixed-rice                    :   10 images
# 134 moon-cake                     :    8 images
# 135 mozuku                        :    7 images
# 136 muffin                        :   11 images
# 137 mushroom-risotto              :    8 images
# 138 nachos                        :    9 images
# 139 namero                        :    5 images
# 140 nanbanzuke                    :   12 images
# 141 nasi-campur                   :   11 images
# 142 nasi-goreng                   :   11 images
# 143 nasi-padang                   :   12 images
# 144 nasi-uduk                     :   17 images
# 145 natto                         :   12 images
# 146 noodles-with-fish-curry       :    8 images
# 147 oatmeal                       :   10 images
# 148 oden                          :    9 images
# 149 okinawa-soba                  :   11 images
# 150 omelet                        :    7 images
# 151 omelet-40                     :   14 images
# 152 omelet-with-fried-rice        :   13 images
# 153 orange                        :    8 images
# 154 oshiruko                      :    6 images
# 155 oxtail-soup                   :   11 images
# 156 oyster-omelette               :    6 images
# 157 paella                        :   10 images
# 158 pancake                       :   10 images
# 159 parfait                       :   12 images
# 160 pho                           :   16 images
# 161 pilaf                         :   10 images
# 162 pizza                         :   10 images
# 163 pizza-toast                   :   11 images
# 164 popcorn                       :   11 images
# 165 pork-belly                    :   12 images
# 166 pork-cutlet                   :    7 images
# 167 pork-cutlet-on-rice           :   12 images
# 168 pork-fillet-cutlet            :   11 images
# 169 pork-loin-cutlet              :    7 images
# 170 pork-miso-soup                :    8 images
# 171 pork-satay                    :   11 images
# 172 pork-sticky-noodles           :    9 images
# 173 pork-with-lemon               :    7 images
# 174 pot-au-feu                    :   11 images
# 175 potage                        :    9 images
# 176 potato-salad                  :    5 images
# 177 raisin-bread                  :   13 images
# 178 ramen-noodle                  :   11 images
# 179 rare-cheese-cake              :    9 images
# 180 rice                          :    6 images
# 181 rice-ball                     :    9 images
# 182 rice-crispy-pork              :   11 images
# 183 rice-gratin                   :   13 images
# 184 rice-gruel                    :   16 images
# 185 rice-vermicelli               :    6 images
# 186 rice-with-roast-duck          :    9 images
# 187 roast-chicken                 :   15 images
# 188 roast-duck                    :   10 images
# 189 roll-bread                    :   11 images
# 190 salmon-meuniere               :   11 images
# 191 salt-and-pepper-fried-shrimp-with-shell:   13 images
# 192 samul                         :   11 images
# 193 sandwiches                    :   12 images
# 194 sashimi                       :   11 images
# 195 sashimi-bowl                  :   15 images
# 196 sausage                       :    9 images
# 197 sauteed-spinach               :   15 images
# 198 sauteed-vegetables            :    8 images
# 199 scone                         :   20 images
# 200 scrambled-egg                 :   12 images
# 201 seasoned-beef-with-potatoes   :   11 images
# 202 shortcake                     :    4 images
# 203 shrimp-patties                :    9 images
# 204 shrimp-with-chill-source      :   12 images
# 205 simmered-pork                 :   15 images
# 206 sirloin-cutlet                :   11 images
# 207 small-steamed-savory-rice-pancake:    5 images
# 208 soba-noodle                   :   12 images
# 209 sour-prawn-soup               :    6 images
# 210 spaghetti                     :    8 images
# 211 spaghetti-meat-sauce          :    8 images
# 212 spam-musubi                   :    8 images
# 213 spicy-chicken-salad           :    8 images
# 214 spicy-chili-flavored-tofu     :    9 images
# 215 steak                         :   12 images
# 216 steamed-egg-hotchpotch        :    7 images
# 217 steamed-meat-dumpling         :   11 images
# 218 steamed-rice-roll             :    6 images
# 219 steamed-spareribs             :    9 images
# 220 stew                          :   10 images
# 221 stewed-pork-leg               :   11 images
# 222 stinky-tofu                   :    6 images
# 223 stir-fried-beef-and-peppers   :   13 images
# 224 stir-fried-mixed-vegetables   :   12 images
# 225 sukiyaki                      :   13 images
# 226 sushi                         :    7 images
# 227 sushi-bowl                    :   12 images
# 228 sweet-and-sour-pork           :   12 images
# 229 tacos                         :    6 images
# 230 takoyaki                      :   11 images
# 231 tanmen                        :   10 images
# 232 tempura                       :    9 images
# 233 tempura-bowl                  :   15 images
# 234 tempura-udon                  :    9 images
# 235 tensin-noodle                 :    7 images
# 236 teriyaki-grilled-fish         :    5 images
# 237 thai-papaya-salad             :   13 images
# 238 thinly-sliced-raw-horsemeat   :   11 images
# 239 three-cup-chicken             :   13 images
# 240 tiramisu                      :   10 images
# 241 toast                         :   11 images
# 242 tortilla                      :   15 images
# 243 trunip-pudding                :    9 images
# 244 twice-cooked-pork             :    7 images
# 245 udon-noodle                   :   10 images
# 246 vegetable-tempura             :   12 images
# 247 vermicelli-noodles-with-snails:   11 images
# 248 waffle                        :   10 images
# 249 winter-melon-soup             :    7 images
# 250 wonton-soup                   :   13 images
# 251 xiao-long-bao                 :    8 images
# 252 yakitori                      :    7 images
# 253 yellow-curry                  :    6 images
# 254 yudofu                        :    5 images
# 255 zha-jiang-mian                :    6 images
# 256 zoni                          :   12 images
# ------------------------------------------------------------

# %%
import yaml

# Use existing split_path from earlier cells
data_yaml_content = {
    'path': str(split_path.resolve()),  # dataset root
    'train': 'train/images',
    'val': 'valid/images',
    'test': 'test/images',
    'nc': len(ds.classes),
    'names': ds.classes
}

# Write unified data.yaml
unified_yaml_path = split_path / 'data.yaml'
with open(unified_yaml_path, 'w') as f:
    yaml.dump(data_yaml_content, f, sort_keys=False)

print(f"Created unified data.yaml at: {unified_yaml_path}")
print(f"Dataset root: {split_path.resolve()}")
print(f"Number of classes: {len(ds.classes)}")
# Out:
# Created unified data.yaml at: /content/split/data.yaml
# Dataset root: /content/split
# Number of classes: 257

# %%
from ultralytics import YOLO


model = YOLO("yolo26m.pt")

training_config = {
    'data': str(unified_yaml_path),

    'epochs': 75,
    'patience': 25, # early stopping if plateau
    'batch': -1,    # auto-batch: trying this out not sure if it works
    'imgsz': 640,   # standard size
    'save': True,
    'save_period': 10,  # checkpoint every 10 epochs

    # Optimizer
    'optimizer': 'AdamW',
    'lr0': 0.001,   # initial learning rate
    'lrf': 0.01,    # final LR = lr0 * lrf
    'momentum': 0.937,
    'weight_decay': 0.0005,
    'warmup_epochs': 3,
    'warmup_momentum': 0.8,
    'cos_lr': True,             # cosine annealing

    # weights
    'box': 7.5,
    'cls': 1.0,
    'dfl': 1.5,
    'close_mosaic': 15,

}
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26m.pt to 'yolo26m.pt': 100% ━━━━━━━━━━━━ 42.2MB 316.8MB/s 0.1s

# %%
try:
    results = model.train(**training_config)
    print("Training completed successfully!")
    print("Model saved to: runs/detect/food_yolov8n/weights/best.pt")
except Exception as e:
    print(f"Training encountered an error: {e}")
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=-1, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=15, cls=1.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/split/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=75, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 175.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=257
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   3194910  ultralytics.nn.modules.head.Detect           [257, 1, True, [256, 512, 512]]
# YOLO26m summary: 280 layers, 22,169,182 parameters, 22,169,182 gradients, 76.9 GFLOPs
#
# Transferred 756/768 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 389.3MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 844.2±303.8 MB/s, size: 28.9 KB)
# train: Scanning /content/split/train/labels... 20148 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20148/20148 1.6Kit/s 12.8s
# train: /content/split/train/images/beef_bowl_012454_jpg.rf.d8599f8ddcbc8c79ba66b21a0f668e10.jpg: 1 duplicate labels removed
# train: New cache created: /content/split/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# AutoBatch: Computing optimal batch size for imgsz=640 at 60.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (NVIDIA A100-SXM4-80GB) 79.25G total, 0.22G reserved, 0.21G allocated, 78.83G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#     22169182       76.92         1.931         83.05           nan        (1, 3, 640, 640)                    list
#     22169182       153.8         4.077         52.21           nan        (2, 3, 640, 640)                    list
#     22169182       307.7         6.862         53.81           nan        (4, 3, 640, 640)                    list
#     22169182       615.4        12.528         61.03           nan        (8, 3, 640, 640)                    list
#     22169182        1231        23.341         67.08           nan       (16, 3, 640, 640)                    list
#     22169182        2461        44.866         90.32           nan       (32, 3, 640, 640)                    list
#     22169182        4923        87.741         175.7           nan       (64, 3, 640, 640)                    list
# AutoBatch: Using batch-size 33 for CUDA:0 46.86G/79.25G (59%) ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1331.9±721.2 MB/s, size: 31.0 KB)
# train: Scanning /content/split/train/labels.cache... 20148 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20148/20148 4.7Git/s 0.0s
# train: /content/split/train/images/beef_bowl_012454_jpg.rf.d8599f8ddcbc8c79ba66b21a0f668e10.jpg: 1 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 714.0±620.1 MB/s, size: 40.1 KB)
# val: Scanning /content/split/valid/labels... 2519 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2519/2519 1.2Kit/s 2.1s
# val: New cache created: /content/split/valid/labels.cache
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.000515625), 136 bias(decay=0.0)
# Plotting labels to /content/runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 75 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/75      19.7G      1.042      8.283     0.0249         54        640: 100% ━━━━━━━━━━━━ 611/611 2.8it/s 3:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 1.1it/s 34.9s
#                    all       2519       2557     0.0137      0.458     0.0329     0.0219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/75        27G      1.111      6.063    0.02672         51        640: 100% ━━━━━━━━━━━━ 611/611 3.1it/s 3:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.4s
#                    all       2519       2557      0.491      0.129      0.118     0.0841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/75        27G      1.062      5.482    0.02549         46        640: 100% ━━━━━━━━━━━━ 611/611 3.2it/s 3:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 3.8it/s 10.3s
#                    all       2519       2557      0.405      0.155      0.134     0.0923
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/75        27G      1.045      5.162    0.02486         53        640: 100% ━━━━━━━━━━━━ 611/611 3.2it/s 3:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.4s
#                    all       2519       2557      0.363      0.271      0.233      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/75        27G      1.016      4.814     0.0241         51        640: 100% ━━━━━━━━━━━━ 611/611 3.2it/s 3:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.5s
#                    all       2519       2557      0.349      0.348      0.329      0.238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/75        27G     0.9804      4.577    0.02321         47        640: 100% ━━━━━━━━━━━━ 611/611 3.2it/s 3:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.5s
#                    all       2519       2557      0.386      0.411      0.388       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/75        27G      0.969      4.377    0.02291         47        640: 100% ━━━━━━━━━━━━ 611/611 3.2it/s 3:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.5s
#                    all       2519       2557       0.35      0.397       0.38      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/75        27G     0.9597      4.194    0.02258         57        640: 100% ━━━━━━━━━━━━ 611/611 3.2it/s 3:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.5s
#                    all       2519       2557      0.444      0.453      0.449      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/75        27G     0.9386      4.026     0.0221         49        640: 100% ━━━━━━━━━━━━ 611/611 3.2it/s 3:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 3.7it/s 10.5s
#                    all       2519       2557      0.448      0.466      0.461      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10
ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /content/runs/detect/train
# Training completed successfully!
# Model saved to: runs/detect/food_yolov8n/weights/best.pt

# %%
# # if collab dies (not sure if this works)
# from ultralytics import YOLO

# model = YOLO('/content/runs/detect/train/weights/last.pt')
# results = model.train(resume=True)

# %%
from google.colab import drive
import shutil

drive.mount('/content/drive')

save_dir = '/content/drive/MyDrive/yolo_weights'
os.makedirs(save_dir, exist_ok=True)

for weight in ['best.pt', 'last.pt']:
    src = f'/content/runs/detect/train/weights/{weight}'
    if os.path.exists(src):
        shutil.copy(src, save_dir)
        print(f"Saved {weight} to {save_dir}")
    else:
        print(f"{weight} not found at {src}")
# Out:
# Mounted at /content/drive
# Saved best.pt to /content/drive/MyDrive/yolo_weights
# Saved last.pt to /content/drive/MyDrive/yolo_weights

# %%
print("Running validation")

best_model = YOLO('/content/runs/detect/train/weights/best.pt')
val_results = best_model.val(data=str(unified_yaml_path))

print("Validation Results:")

print(f"mAP@0.5: {val_results.box.map50:.4f}")
print(f"mAP@0.5:0.95: {val_results.box.map:.4f}")
print(f"Precision: {val_results.box.mp:.4f}")
print(f"Recall: {val_results.box.mr:.4f}")
# Out:
# Running validation
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# YOLO26m summary (fused): 132 layers, 20,547,599 parameters, 0 gradients, 68.9 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1099.6±273.2 MB/s, size: 38.7 KB)
# val: Scanning /content/split/valid/labels.cache... 2519 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2519/2519 704.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 158/158 11.2it/s 14.2s
#                    all       2519       2557      0.725       0.69      0.771       0.61
#                  adobo          7          7      0.573      0.575      0.626      0.534
#           almond-jelly          9          9        0.6      0.667      0.745      0.466
#                  apple          7         18       0.84      0.877      0.911      0.789
#              apple-pie          7          7      0.726      0.762      0.895       0.79
#             ayam-bakar         11         11      0.841      0.545      0.822      0.585
#            ayam-goreng          8          8      0.353       0.25      0.406      0.364
#            babi-guling          6          6        0.7      0.782      0.795      0.638
#                  bagel         10         10      0.835        0.8      0.916       0.82
#            bak-kut-teh         11         11      0.627      0.613      0.822      0.656
#           baked-salmon          3          3      0.439      0.667      0.806      0.604
# ball-shaped-bun-with-pork         13         13          1      0.425       0.72      0.525
# barbecued-red-pork-in-sauce-with-rice         11         11      0.868        0.6      0.755      0.697
# bean-curd-family-style         14         14      0.829      0.714       0.84      0.678
#              beef-bowl         10         10      0.765        0.9      0.905      0.785
#             beef-curry          6          6      0.407        0.5      0.265      0.216
#   beef-in-oyster-sauce         10         10      0.619        0.4      0.501      0.438
#            beef-noodle         11         11      0.892      0.818      0.865      0.632
#       beef-noodle-soup         10         10      0.864      0.636      0.767      0.619
#               bibimbap          8          8      0.708      0.875      0.892      0.827
# boiled-chicken-and-vegetables         12         12       0.65      0.833      0.774      0.542
#            boiled-fish         14         14      0.807      0.643      0.721      0.513
# boned-sliced-hainan-style-chicken-with-marinated-rice         10         10      0.797      0.786      0.858      0.769
# braised-pork-meat-ball-with-napa-cabbage          8          8          1      0.615      0.814       0.53
#       broiled-eel-bowl         10         10      0.832          1      0.978      0.803
#                brownie          8          8      0.874      0.868      0.897      0.852
#    sweet-and-sour-pork          7          7      0.608      0.857      0.868      0.868
#                  tacos         11         11      0.945      0.545      0.842      0.464
#               takoyaki          8          8      0.589      0.875      0.801      0.483
#                 tanmen          8          8      0.402      0.375      0.418      0.353
#                tempura          8          8      0.775      0.864      0.874      0.644
#           tempura-bowl          8          8      0.836      0.636      0.792      0.561
#           tempura-udon          6          6      0.739      0.833      0.832      0.649
#          tensin-noodle         13         13      0.909      0.923      0.955      0.744
#  teriyaki-grilled-fish         13         13      0.677      0.647       0.73      0.585
#      thai-papaya-salad          9          9       0.87      0.778      0.867      0.769
# thinly-sliced-raw-horsemeat         12         12      0.877      0.917      0.979      0.754
#      three-cup-chicken         10         10      0.817        0.8      0.951      0.786
#               tiramisu         14         14      0.867      0.929      0.986      0.817
#                  toast         14         14      0.776      0.714      0.768      0.548
#               tortilla          7          7      0.447      0.429      0.419      0.302
#         trunip-pudding          9          9      0.889      0.889      0.934      0.837
#      twice-cooked-pork          8          8      0.534      0.625      0.654       0.52
#            udon-noodle         13         13      0.879      0.846      0.837      0.667
#      vegetable-tempura          8          8      0.606       0.75       0.76      0.544
# vermicelli-noodles-with-snails         14         14      0.712      0.714      0.833       0.69
#                 waffle         11         11      0.948      0.909      0.981      0.907
#      winter-melon-soup         11         11      0.795      0.707      0.924      0.556
#            wonton-soup          9          9      0.616      0.556      0.653      0.397
#          xiao-long-bao          7          7      0.641      0.857      0.876      0.757
#               yakitori          9          9      0.821      0.889      0.975      0.779
#           yellow-curry          8          8      0.745       0.75      0.723      0.666
#                 yudofu         14         14      0.674      0.714      0.829      0.648
#         zha-jiang-mian         10         10      0.947        0.7      0.882      0.743
#                   zoni          7          7      0.421      0.857      0.461      0.383
# Speed: 0.5ms preprocess, 2.6ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /content/runs/detect/val
# Validation Results:
# mAP@0.5: 0.7707
# mAP@0.5:0.95: 0.6102
# Precision: 0.7253
# Recall: 0.6903

# %%
print("Running on test set")

test_results = best_model.val(data=str(unified_yaml_path), split='test')

print("Test Results:")
print(f"mAP@0.5: {test_results.box.map50:.4f}")
print(f"mAP@0.5:0.95: {test_results.box.map:.4f}")
print(f"Precision: {test_results.box.mp:.4f}")
print(f"Recall: {test_results.box.mr:.4f}")
# Out:
# Running on test set
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1021.4±536.3 MB/s, size: 30.0 KB)
# val: Scanning /content/split/test/labels... 2519 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2519/2519 1.6Kit/s 1.6s
# val: New cache created: /content/split/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 158/158 11.9it/s 13.3s
#                    all       2519       2553      0.743       0.68      0.766      0.612
#                  adobo          5          5      0.554        0.2      0.638      0.612
#           almond-jelly          7          7      0.715      0.857      0.769      0.638
#                  apple         13         27      0.918      0.741      0.796      0.688
#              apple-pie          5          5      0.607        0.8      0.686        0.6
#             ayam-bakar         11         11      0.963      0.545      0.762       0.64
#            ayam-goreng          7          7      0.344      0.143      0.268      0.251
#            babi-guling          3          3      0.746      0.667      0.764      0.636
#                  bagel         13         13      0.906      0.743      0.844      0.722
