# %%
# %pip install roboflow
# %pip install python-dotenv
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 26.0
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.2 -> 26.0
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Running on VSCode
from dotenv import load_dotenv
import os

load_dotenv()

from roboflow import Roboflow

api_key = os.getenv("ROBOFLOW_API_KEY")

rf = Roboflow(api_key=api_key)
project = rf.workspace("caretech-qnw0y").project("v1-caretech-combined-dataset")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#      11 rf = Roboflow(api_key=api_key)
#      12 project = rf.workspace("caretech-qnw0y").project("v1-caretech-combined-dataset")
# ---> 13 dataset = project.version(1).download("yolov8")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/roboflow/core/version.py:241, in Version.download(self, model_format, location, overwrite)
#     237         raise RuntimeError(export_info)
#     239     link = export_info["export"]["link"]
# --> 241 self.__download_zip(link, location, model_format)
#     242 self.__extract_zip(location, model_format)
#     243 self.__reformat_yaml(location, model_format)  # TODO: is roboflow-python a place to be munging yaml files?
#
# ...

# %%
# Sanity Check

import os, glob

for root, dirs, files in os.walk("/Users/rushildileep/Documents/vitamin-tracking/rushil_king/V1-CareTech-Combined-Dataset-1", topdown=True):
    if os.path.basename(root) == "images":
        print("IMAGES FOLDER:", root)
        imgs = glob.glob(os.path.join(root, "*.jpg"))
        print("IMAGES FOLDER:", root, "->", len(imgs))
# Out:
# IMAGES FOLDER: /Users/rushildileep/Documents/vitamin-tracking/rushil_king/V1-CareTech-Combined-Dataset-1/valid/images
# IMAGES FOLDER: /Users/rushildileep/Documents/vitamin-tracking/rushil_king/V1-CareTech-Combined-Dataset-1/valid/images -> 5822
# IMAGES FOLDER: /Users/rushildileep/Documents/vitamin-tracking/rushil_king/V1-CareTech-Combined-Dataset-1/test/images
# IMAGES FOLDER: /Users/rushildileep/Documents/vitamin-tracking/rushil_king/V1-CareTech-Combined-Dataset-1/test/images -> 2949
# IMAGES FOLDER: /Users/rushildileep/Documents/vitamin-tracking/rushil_king/V1-CareTech-Combined-Dataset-1/train/images
# IMAGES FOLDER: /Users/rushildileep/Documents/vitamin-tracking/rushil_king/V1-CareTech-Combined-Dataset-1/train/images -> 20509

# %%
# %pip install ultralytics
# Out:
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#   Using cached markupsafe-3.0.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.7 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 MB 11.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.7/805.7 kB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.7/39.7 MB 12.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 9.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 MB 8.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# CHANGE MODEL HERE
model = YOLO("yolov8x.pt")

model.info()

# Change this to different data path
results = model.train(data="/Users/rushildileep/Documents/vitamin-tracking/rushil_king/V1-CareTech-Combined-Dataset-1/data.yaml", epochs=40)
# Out:
# YOLOv8x summary: 209 layers, 68,229,648 parameters, 0 gradients, 258.5 GFLOPs
# Ultralytics 8.4.11 🚀 Python-3.12.6 torch-2.10.0 CPU (Apple M3 Pro)
# ...
